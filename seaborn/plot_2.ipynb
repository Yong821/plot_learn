# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
titanic=sns.load_dataset('titanic')
titanic.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 708         1       1  female  22.0      0      0  151.5500        S   First
# 291         1       1  female  19.0      1      0   91.0792        C   First
# 83          0       1    male  28.0      0      0   47.1000        S   First
# 514         0       3    male  24.0      0      0    7.4958        S   Third
# 451         0       3    male   NaN      1      0   19.9667        S   Third
# 283         1       3    male  19.0      0      0    8.0500        S   Third
# 440         1       2  female  45.0      1      1   26.2500        S  Second
# 182         0       3    male   9.0      4      2   31.3875        S   Third
# 231         0       3    male  29.0      0      0    7.7750        S   Third
# 716         1       1  female  38.0      0      0  227.5250        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 708  woman       False  NaN  Southampton   yes   True
# 291  woman       False    B    Cherbourg   yes  False
# 83     man        True  NaN  Southampton    no   True
# 514    man        True  NaN  Southampton    no   True
# 451    man        True  NaN  Southampton    no  False
# 283    man        True  NaN  Southampton   yes   True
# 440  woman       False  NaN  Southampton   yes  False
# 182  child       False  NaN  Southampton    no  False
# 231    man        True  NaN  Southampton    no   True
# 716  woman       False    C    Cherbourg   yes   True

# %%
age1 = titanic['age'].dropna()
sns.distplot(age1)
# Out:
# /tmp/ipykernel_785839/4157091797.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age1)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
sns.distplot(age1, ax=axes[0], hist_kws={'color':'green', 'label':'hist'}, kde_kws={'color':'yellow'})
sns.distplot(age1, ax=axes[1], rug=True)
# Out:
# /tmp/ipykernel_785839/857256409.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age1, ax=axes[0], hist_kws={'color':'green', 'label':'hist'}, kde_kws={'color':'yellow'})
# /tmp/ipykernel_785839/857256409.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age1, ax=axes[1], rug=True)
# <AxesSubplot:xlabel='age', ylabel='Density'>
