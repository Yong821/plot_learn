# %%
import matplotlib.pyplot as plt

# %%
langs = ['C', 'C++', 'Go', 'Java']
x = [12, 23, 10, 32]
fig, ax = plt.subplots()
ax.pie(x, labels=langs, autopct='%1.3f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f39add8c460>,
# ...
#  [Text(0.9707737407549583, 0.5172990858880628, 'C'),
#   Text(-0.37387816633027815, 1.0345120186549353, 'C++'),
#   Text(-1.0917703657228106, -0.13430364302386125, 'Go'),
#   Text(0.2883117531348274, -1.0615443151391855, 'Java')],
#  [Text(0.5295129495027044, 0.28216313775712515, '15.584%'),
#   Text(-0.20393354527106078, 0.5642792829026919, '29.870%'),
#   Text(-0.5955111085760784, -0.07325653255846976, '12.987%'),
#   Text(0.15726095625536035, -0.5790241718941012, '41.558%')])
