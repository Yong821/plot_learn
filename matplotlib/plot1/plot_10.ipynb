# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
x = np.arange(1, 5, 1)
fig, ax = plt.subplots(1, 2)
ax[0].plot(x, np.exp(x))
ax[1].plot(x, np.exp(x))
ax[1].set_xlim(1, 10)
# Out:
# (1.0, 10.0)
